# %%
import pandas as pd
import numpy as np

# %%
studdata=pd.read_excel('student_data_excel.xlsx')

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow       94.27         237.19
# 1            2        Devy      Rickwood       25.76         263.38
# 2            3      Pennie         Wayne       99.48         258.87
# 3            4    Shurlock          Pitt        4.28         287.94
# 4            5         Koo        Gibben        7.22         183.33
# 5            6     Rebecca        Gamlyn        5.22         179.31
# 6            7       Darda        Putley       89.62         208.78
# 7            8      Alisha     Shotboult       76.16            NaN
# 8            9       Clywd         Assur       62.68         138.52
# 9           10       Gibby         Falck       17.57         253.70
# 10          11     Winonah     Heathwood       74.68          78.23
# 11          12      Harley        Kerner       59.69          88.83
# 12          13     Georgie        Hamley       29.03         224.13
# ...

# %%
studdata.shape
# Out:
# (58, 9)

# %%
studdata.describe()
# Out:
#        student_id  math_marks  science_marks  english_marks  social_marks  \
# count   58.000000   57.000000      41.000000      49.000000     28.000000
# mean    26.275862   45.912105     161.719756       9.950612    114.888571
# std     14.696691   31.437007      80.987577     107.348471     57.467542
# min      1.000000    2.960000      15.840000    -619.850000     21.660000
# 25%     14.250000   17.570000      88.830000       1.520000     56.052500
# 50%     26.000000   43.100000     158.540000      33.940000    120.815000
# 75%     38.750000   76.160000     231.490000      68.170000    160.185000
# max     50.000000   99.480000     299.690000      99.680000    199.500000
#
#        computerscience_marks  statistics_marks
# count              58.000000               0.0
# mean              213.251897               NaN
# std               106.557808               NaN
# min                16.630000               NaN
# 25%               131.377500               NaN
# ...

# %%
studdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             58 non-null     int64
#  1   first_name             58 non-null     object
#  2   last_name              58 non-null     object
#  3   math_marks             57 non-null     float64
#  4   science_marks          41 non-null     float64
#  5   english_marks          49 non-null     float64
#  6   social_marks           28 non-null     float64
#  7   computerscience_marks  58 non-null     float64
#  8   statistics_marks       0 non-null      float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 4.2+ KB

# %%
studdata.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# dtype: bool

# %%
studdata.drop_duplicates()
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow       94.27         237.19
# 1            2        Devy      Rickwood       25.76         263.38
# 2            3      Pennie         Wayne       99.48         258.87
# 3            4    Shurlock          Pitt        4.28         287.94
# 4            5         Koo        Gibben        7.22         183.33
# 5            6     Rebecca        Gamlyn        5.22         179.31
# 6            7       Darda        Putley       89.62         208.78
# 7            8      Alisha     Shotboult       76.16            NaN
# 8            9       Clywd         Assur       62.68         138.52
# 9           10       Gibby         Falck       17.57         253.70
# 10          11     Winonah     Heathwood       74.68          78.23
# 11          12      Harley        Kerner       59.69          88.83
# 12          13     Georgie        Hamley       29.03         224.13
# ...

# %%
studdata=studdata.drop(['statistics_marks'],axis=1)

# %%
studdata=studdata.rename(columns={"social_marks": "statistics_marks"})

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow       94.27         237.19
# 1            2        Devy      Rickwood       25.76         263.38
# 2            3      Pennie         Wayne       99.48         258.87
# 3            4    Shurlock          Pitt        4.28         287.94
# 4            5         Koo        Gibben        7.22         183.33
# 5            6     Rebecca        Gamlyn        5.22         179.31
# 6            7       Darda        Putley       89.62         208.78
# 7            8      Alisha     Shotboult       76.16            NaN
# 8            9       Clywd         Assur       62.68         138.52
# 9           10       Gibby         Falck       17.57         253.70
# 10          11     Winonah     Heathwood       74.68          78.23
# 11          12      Harley        Kerner       59.69          88.83
# 12          13     Georgie        Hamley       29.03         224.13
# ...

# %%
mathmean=studdata['math_marks'].mean()

# %%
mathmean
# Out:
# 45.9121052631579

# %%
studdata['math_marks'].fillna(value=mathmean, inplace=True)

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000         237.19
# 1            2        Devy      Rickwood   25.760000         263.38
# 2            3      Pennie         Wayne   99.480000         258.87
# 3            4    Shurlock          Pitt    4.280000         287.94
# 4            5         Koo        Gibben    7.220000         183.33
# 5            6     Rebecca        Gamlyn    5.220000         179.31
# 6            7       Darda        Putley   89.620000         208.78
# 7            8      Alisha     Shotboult   76.160000            NaN
# 8            9       Clywd         Assur   62.680000         138.52
# 9           10       Gibby         Falck   17.570000         253.70
# 10          11     Winonah     Heathwood   74.680000          78.23
# 11          12      Harley        Kerner   59.690000          88.83
# 12          13     Georgie        Hamley   29.030000         224.13
# ...

# %%
studdata['science_marks'].fillna(value=studdata['science_marks'].mean(), inplace=True)

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000     237.190000
# 1            2        Devy      Rickwood   25.760000     263.380000
# 2            3      Pennie         Wayne   99.480000     258.870000
# 3            4    Shurlock          Pitt    4.280000     287.940000
# 4            5         Koo        Gibben    7.220000     183.330000
# 5            6     Rebecca        Gamlyn    5.220000     179.310000
# 6            7       Darda        Putley   89.620000     208.780000
# 7            8      Alisha     Shotboult   76.160000     161.719756
# 8            9       Clywd         Assur   62.680000     138.520000
# 9           10       Gibby         Falck   17.570000     253.700000
# 10          11     Winonah     Heathwood   74.680000      78.230000
# 11          12      Harley        Kerner   59.690000      88.830000
# 12          13     Georgie        Hamley   29.030000     224.130000
# ...

# %%
studdata['english_marks'].fillna(value=studdata['english_marks'].mean(), inplace=True)

# %%
studdata['english_marks']
# Out:
# 0      23.430000
# 1    -619.850000
# 2     -93.320000
# 3       7.380000
# 4      68.170000
# 5      70.170000
# 6       9.950612
# 7      79.090000
# 8       9.950612
# 9      74.710000
# 10     28.470000
# 11     51.850000
# 12      9.950612
# 13     86.970000
# 14     92.050000
# 15    -96.040000
# 16      4.370000
# 17     49.400000
# 18    -99.270000
# 19     67.000000
# 20     45.420000
# 21     82.350000
# 22      9.950612
# 23     99.680000
# 24      1.520000
# 25      2.740000
# 26     76.470000
# 27    -37.320000
# 28     33.940000
# 29      9.950612
# 30     40.250000
# 31    -48.360000
# 32     26.720000
# 33    -21.590000
# 34     97.450000
# 35      9.950612
# 36     40.480000
# 37      5.530000
# 38     34.810000
# 39      6.900000
# 40     34.260000
# 41     -8.560000
# 42     62.270000
# 43    -63.080000
# 44     84.560000
# 45     74.410000
# 46    -53.230000
# 47     19.280000
# 48     45.090000
# 49      9.950612
# 50     51.850000
# 51      2.740000
# ...

# %%
studdata['statistics_marks'].fillna(value=studdata['statistics_marks'].mean(), inplace=True)

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000     237.190000
# 1            2        Devy      Rickwood   25.760000     263.380000
# 2            3      Pennie         Wayne   99.480000     258.870000
# 3            4    Shurlock          Pitt    4.280000     287.940000
# 4            5         Koo        Gibben    7.220000     183.330000
# 5            6     Rebecca        Gamlyn    5.220000     179.310000
# 6            7       Darda        Putley   89.620000     208.780000
# 7            8      Alisha     Shotboult   76.160000     161.719756
# 8            9       Clywd         Assur   62.680000     138.520000
# 9           10       Gibby         Falck   17.570000     253.700000
# 10          11     Winonah     Heathwood   74.680000      78.230000
# 11          12      Harley        Kerner   59.690000      88.830000
# 12          13     Georgie        Hamley   29.030000     224.130000
# ...

# %%
for i in studdata.index:
    if studdata.loc[i,'english_marks']<0.0:
                    studdata.loc[i,'english_marks']=0

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000     237.190000
# 1            2        Devy      Rickwood   25.760000     263.380000
# 2            3      Pennie         Wayne   99.480000     258.870000
# 3            4    Shurlock          Pitt    4.280000     287.940000
# 4            5         Koo        Gibben    7.220000     183.330000
# 5            6     Rebecca        Gamlyn    5.220000     179.310000
# 6            7       Darda        Putley   89.620000     208.780000
# 7            8      Alisha     Shotboult   76.160000     161.719756
# 8            9       Clywd         Assur   62.680000     138.520000
# 9           10       Gibby         Falck   17.570000     253.700000
# 10          11     Winonah     Heathwood   74.680000      78.230000
# 11          12      Harley        Kerner   59.690000      88.830000
# 12          13     Georgie        Hamley   29.030000     224.130000
# ...

# %%
for i in studdata.index:
    if studdata.loc[i,'statistics_marks']>100:
                    studdata.loc[i,'statistics_marks']=100

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000     237.190000
# 1            2        Devy      Rickwood   25.760000     263.380000
# 2            3      Pennie         Wayne   99.480000     258.870000
# 3            4    Shurlock          Pitt    4.280000     287.940000
# 4            5         Koo        Gibben    7.220000     183.330000
# 5            6     Rebecca        Gamlyn    5.220000     179.310000
# 6            7       Darda        Putley   89.620000     208.780000
# 7            8      Alisha     Shotboult   76.160000     161.719756
# 8            9       Clywd         Assur   62.680000     138.520000
# 9           10       Gibby         Falck   17.570000     253.700000
# 10          11     Winonah     Heathwood   74.680000      78.230000
# 11          12      Harley        Kerner   59.690000      88.830000
# 12          13     Georgie        Hamley   29.030000     224.130000
# ...

# %%
for i in studdata.index:
    if studdata.loc[i,'science_marks']>100:
                    studdata.loc[i,'science_marks']=100

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000         100.00
# 1            2        Devy      Rickwood   25.760000         100.00
# 2            3      Pennie         Wayne   99.480000         100.00
# 3            4    Shurlock          Pitt    4.280000         100.00
# 4            5         Koo        Gibben    7.220000         100.00
# 5            6     Rebecca        Gamlyn    5.220000         100.00
# 6            7       Darda        Putley   89.620000         100.00
# 7            8      Alisha     Shotboult   76.160000         100.00
# 8            9       Clywd         Assur   62.680000         100.00
# 9           10       Gibby         Falck   17.570000         100.00
# 10          11     Winonah     Heathwood   74.680000          78.23
# 11          12      Harley        Kerner   59.690000          88.83
# 12          13     Georgie        Hamley   29.030000         100.00
# ...

# %%
for i in studdata.index:
    if studdata.loc[i,'computerscience_marks']>100:
                    studdata.loc[i,'computerscience_marks']=100

# %%
studdata
# Out:
#     student_id  first_name     last_name  math_marks  science_marks  \
# 0            1     Devonne        Elstow   94.270000         100.00
# 1            2        Devy      Rickwood   25.760000         100.00
# 2            3      Pennie         Wayne   99.480000         100.00
# 3            4    Shurlock          Pitt    4.280000         100.00
# 4            5         Koo        Gibben    7.220000         100.00
# 5            6     Rebecca        Gamlyn    5.220000         100.00
# 6            7       Darda        Putley   89.620000         100.00
# 7            8      Alisha     Shotboult   76.160000         100.00
# 8            9       Clywd         Assur   62.680000         100.00
# 9           10       Gibby         Falck   17.570000         100.00
# 10          11     Winonah     Heathwood   74.680000          78.23
# 11          12      Harley        Kerner   59.690000          88.83
# 12          13     Georgie        Hamley   29.030000         100.00
# ...
